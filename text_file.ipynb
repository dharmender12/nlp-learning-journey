# %%
file = open("Hi.txt", "w")
file.write("NLP is fun.")
file.write("Python is also fun.")
file.close()

# %%
file = open("Hi.txt",'r')
print(file.read())
file.close()
# Out:
# NLP is fun.Python is also fun.

# %%
file = open("Hi.txt", "r")
for line in file: 
    print("line",line.strip())

file.close()
# Out:
# line NLP is fun.Python is also fun.

# %%
# !pip install pymupdf

# %%
import fitz
pdf = fitz.open("sample.pdf")
text = ""
for page in pdf:
    text += page.get_text()
pdf.close()
print(text[:500])  # Print the first 500 characters of the extracted text
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_61734/2023993159.py in ?()
#       1 import fitz
# ----> 2 pdf = fitz.open("sample.pdf")
#       3 text = ""
#       4 for page in pdf:
#       5     text += page.get_text()
#
# ~/anaconda3/lib/python3.10/site-packages/pymupdf/__init__.py in ?(self, filename, stream, filetype, rect, width, height, fontsize)
#    3061                     self.page_count2 = extra.page_count_pdf
#    3062                 else:
#    3063                     self.page_count2 = extra.page_count_fz
#    3064         finally:
# -> 3065             JM_mupdf_show_errors = JM_mupdf_show_errors_old
#
# FileNotFoundError: no such file: 'sample.pdf'
